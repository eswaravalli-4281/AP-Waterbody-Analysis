# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("WBC_AP.csv")
df.head(10)
# Out:
#   rural_or_urban      State Name  District Name Block/Tehsil Name  \
# 0          Rural  ANDHRA PRADESH     ANANTHAPUR       VENKATAGIRI
# 1          Rural  ANDHRA PRADESH  WEST GODAVARI           AKIVIDU
# 2          Rural  ANDHRA PRADESH  WEST GODAVARI           AKIVIDU
# 3          Rural  ANDHRA PRADESH        KURNOOL      Kolimigundla
# 4          Rural  ANDHRA PRADESH  WEST GODAVARI         BHIMADOLE
# 5          Rural  ANDHRA PRADESH        KURNOOL        Chippagiri
# 6          Rural  ANDHRA PRADESH  WEST GODAVARI        BHIMAVARAM
# 7          Rural  ANDHRA PRADESH            YSR       YERRAGUNTLA
# 8          Rural  ANDHRA PRADESH  WEST GODAVARI        BHIMAVARAM
# 9          Rural  ANDHRA PRADESH  WEST GODAVARI        BHIMAVARAM
#
#       Village Name town_municipalty_name ward_name  \
# 0         Rayadurg                   NaN       NaN
# 1    Pedakapavaram                   NaN       NaN
# 2         Taratava                   NaN       NaN
# 3  Chintalayapalle                   NaN       NaN
# 4      Agadallanka                   NaN       NaN
# 5          Nemakal                   NaN       NaN
# 6        Anakoderu                   NaN       NaN
# 7      Peddanapadu                   NaN       NaN
# 8        Anakoderu                   NaN       NaN
# 9        Anakoderu                   NaN       NaN
#
#    si_no_of_water_body_within_village_town                   unique_id  \
# 0                                        1  1/28/550/005187/R00704/001
# 1                                        1  1/28/546/004975/588589/001
# 2                                       68  1/28/546/004975/588592/068
# 3                                        6  1/28/552/005301/594589/006
# 4                                       61  1/28/546/004963/588362/061
# 5                                       10  1/28/552/005291/594425/010
# 6                                       14  1/28/546/004984/588734/014
# 7                                        7  1/28/551/005223/593284/007
# 8                                       47  1/28/546/004984/588734/047
# 9                                       51  1/28/546/004984/588734/051
#
#               water_body_name  ... no_people_benefited_by_water_body  \
# 0                     Cheruvu  ...                             298.0
# 1           Panchaiti cheruvu  ...                            3500.0
# 2    Mallareddy Srinivasarao7  ...                               3.0
# 3               sirlarchuruvu  ...                               4.0
# 4                    Fishtank  ...                               1.0
# 5                   Farm pond  ...                               NaN
# 6            Alluri subbaraju  ...                               1.0
# 7                   CHECK DAM  ...                               NaN
# 8       Vegesna narayana raju  ...                               1.0
# 9  Vegesna suryanarayana raju  ...                               1.0
#
#   ref_selection_id_wua_exists_name extent_of_area_covered_by_wua  \
# 0                               No                           NaN
# 1                               No                           NaN
# 2                              NaN                           NaN
# 3                               No                           NaN
# 4                              NaN                           NaN
# 5                              NaN                           NaN
# 6                              NaN                           NaN
# 7                               No                           NaN
# 8                              NaN                           NaN
# 9                              NaN                           NaN
#
#   number_of_wua_formed ref_selection_id_dip_sip_exists_name  \
# 0                  NaN                                  Yes
# 1                  NaN                                  Yes
# 2                  NaN                                   No
# 3                  NaN                                  Yes
# 4                  NaN                                   No
# 5                  NaN                                   No
# 6                  NaN                                   No
# 7                  NaN                                  Yes
# 8                  NaN                                   No
# 9                  NaN                                   No
#
#   ref_selection_id_water_body_encroached_name  \
# 0                                          No
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          No
# 5                                          No
# 6                                          No
# 7                                          No
# 8                                          No
# 9                                          No
#
#   ref_selection_id_encroachment_assessed_name area_encroached_percentage  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# 5                                         NaN                        NaN
# 6                                         NaN                        NaN
# 7                                         NaN                        NaN
# 8                                         NaN                        NaN
# 9                                         NaN                        NaN
#
#   reason_water_body_in_use_name2  reason_water_body_in_use_name3
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# 5                            NaN                             NaN
# 6                            NaN                             NaN
# 7                            NaN                             NaN
# 8                            NaN                             NaN
# 9                            NaN                             NaN
#
# [10 rows x 53 columns]

# %%
df.columns
# Out:
# Index(['rural_or_urban', 'State Name', 'District Name', 'Block/Tehsil Name',
#        'Village Name', 'town_municipalty_name', 'ward_name',
#        'si_no_of_water_body_within_village_town', 'unique_id',
#        'water_body_name', 'basin_name', 'sub_basin_name',
#        'ref_water_body_type_id_name', 'nature_of_storage', 'khasra_number',
#        'water_body_loc_name', 'water_body_ownership_name',
#        'ref_water_body_in_use_id_name',
#        'ref_reason_water_body_in_use_id1_name', 'cca_water_body',
#        'ipc_water_body', 'scheme_status_reason_name', 'water_body_nature_name',
#        'manmade_water_body_type_name', 'construcion_year', 'construction_cost',
#        'renovation_year', 'renovation_cost',
#        'ref_water_body_under_repair_renovation_restoration_id_name',
#        'scheme_under_revival_is_done', 'scheme_inclusion_year',
#        'targeted_completion_year', 'estimated_cost',
#        'target_potential_revival', 'irrigation_potential_revived',
#        'water_spread_area_of_water_body', 'max_depth_water_body_fully_filled',
#        'storage_capacity_water_body_original',
#        'storage_capacity_water_body_present', 'filled_up_storage_name',
#        'filled_up_storage_space_name', 'no_town_cities_benefited',
#        'no_villages_benefited', 'no_people_benefited_by_water_body',
#        'ref_selection_id_wua_exists_name', 'extent_of_area_covered_by_wua',
#        'number_of_wua_formed', 'ref_selection_id_dip_sip_exists_name',
#        'ref_selection_id_water_body_encroached_name',
#        'ref_selection_id_encroachment_assessed_name',
#        'area_encroached_percentage', 'reason_water_body_in_use_name2',
#        'reason_water_body_in_use_name3'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# rural_or_urban                                                     0
# State Name                                                         0
# District Name                                                      0
# Block/Tehsil Name                                                514
# Village Name                                                     514
# town_municipalty_name                                         190263
# ward_name                                                     190263
# si_no_of_water_body_within_village_town                            0
# unique_id                                                          0
# water_body_name                                                  256
# basin_name                                                         0
# sub_basin_name                                                 91777
# ref_water_body_type_id_name                                        0
# nature_of_storage                                             185813
# khasra_number                                                      1
# water_body_loc_name                                                0
# water_body_ownership_name                                          0
# ref_water_body_in_use_id_name                                      0
# ref_reason_water_body_in_use_id1_name                          41498
# cca_water_body                                                153313
# ipc_water_body                                                152839
# scheme_status_reason_name                                     149279
# water_body_nature_name                                             0
# manmade_water_body_type_name                                   26016
# construcion_year                                               14930
# construction_cost                                              13118
# renovation_year                                                41772
# renovation_cost                                                41772
# ref_water_body_under_repair_renovation_restoration_id_name         0
# scheme_under_revival_is_done                                  186809
# scheme_inclusion_year                                         186809
# targeted_completion_year                                      186809
# estimated_cost                                                186791
# target_potential_revival                                      186791
# irrigation_potential_revived                                  186791
# water_spread_area_of_water_body                                53556
# max_depth_water_body_fully_filled                              53521
# storage_capacity_water_body_original                           61195
# storage_capacity_water_body_present                            61196
# filled_up_storage_name                                         62455
# filled_up_storage_space_name                                   62455
# no_town_cities_benefited                                      190165
# no_villages_benefited                                          29820
# no_people_benefited_by_water_body                              29820
# ref_selection_id_wua_exists_name                               98518
# extent_of_area_covered_by_wua                                 181446
# number_of_wua_formed                                          181472
# ref_selection_id_dip_sip_exists_name                               0
# ref_selection_id_water_body_encroached_name                        0
# ref_selection_id_encroachment_assessed_name                   186857
# area_encroached_percentage                                    188029
# reason_water_body_in_use_name2                                171445
# reason_water_body_in_use_name3                                180519
# dtype: int64

# %%
columns_to_drop = [
'si_no_of_water_body_within_village_town',
'unique_id',
'water_body_name',
'khasra_number',
'water_body_loc_name',
'town_municipalty_name',
'ward_name',
'scheme_under_revival_is_done',
'scheme_inclusion_year',
'targeted_completion_year',
'estimated_cost',
'target_potential_revival',
'irrigation_potential_revived',
'extent_of_area_covered_by_wua',
'number_of_wua_formed',
'no_town_cities_benefited',
'ref_selection_id_encroachment_assessed_name',
'area_encroached_percentage',
'Village Name'
]

# %%
df = df.drop(columns=columns_to_drop)

# %%
cols_to_drop = [
    'nature_of_storage',
    'scheme_status_reason_name',
    'reason_water_body_in_use_name2',
    'reason_water_body_in_use_name3'
]

df = df.drop(columns=cols_to_drop)

# %%
df['cca_water_body'] = df['cca_water_body'].fillna(0)

# %%
df['ipc_water_body'] = df['ipc_water_body'].fillna(0)

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
cat_cols = df.select_dtypes(include=['object']).columns

for col in cat_cols:
    df[col] = df[col].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# rural_or_urban                                                0
# State Name                                                    0
# District Name                                                 0
# Block/Tehsil Name                                             0
# basin_name                                                    0
# sub_basin_name                                                0
# ref_water_body_type_id_name                                   0
# water_body_ownership_name                                     0
# ref_water_body_in_use_id_name                                 0
# ref_reason_water_body_in_use_id1_name                         0
# cca_water_body                                                0
# ipc_water_body                                                0
# water_body_nature_name                                        0
# manmade_water_body_type_name                                  0
# construcion_year                                              0
# construction_cost                                             0
# renovation_year                                               0
# renovation_cost                                               0
# ref_water_body_under_repair_renovation_restoration_id_name    0
# water_spread_area_of_water_body                               0
# max_depth_water_body_fully_filled                             0
# storage_capacity_water_body_original                          0
# storage_capacity_water_body_present                           0
# filled_up_storage_name                                        0
# filled_up_storage_space_name                                  0
# no_villages_benefited                                         0
# no_people_benefited_by_water_body                             0
# ref_selection_id_wua_exists_name                              0
# ref_selection_id_dip_sip_exists_name                          0
# ref_selection_id_water_body_encroached_name                   0
# dtype: int64

# %%
df['District Name'].value_counts()
df['District Name'].value_counts().sort_values(ascending=False).plot(
    kind='bar',
    figsize=(12,6),
    title='Number of Water Bodies per District'
)
# Out:
# <Axes: title={'center': 'Number of Water Bodies per District'}, xlabel='District Name'>

# %%
df.groupby('District Name')['storage_capacity_water_body_present'] \
  .mean() \
  .sort_values(ascending=False) \
  .plot(kind='bar', figsize=(12,6),
        title='Average Storage Capacity per Water Body by District')
# Out:
# <Axes: title={'center': 'Average Storage Capacity per Water Body by District'}, xlabel='District Name'>

# %%
df.groupby('District Name')['storage_capacity_water_body_present'] \
  .sum() \
  .sort_values(ascending=False) \
  .plot(kind='bar', figsize=(12,6),
        title='Total Water Storage Capacity by District')
# Out:
# <Axes: title={'center': 'Total Water Storage Capacity by District'}, xlabel='District Name'>

# %%
df.groupby('District Name')['no_people_benefited_by_water_body'] \
  .sum() \
  .sort_values(ascending=False) \
  .plot(kind='bar', figsize=(12,6),
        title='Population Benefited by Water Bodies per District')
# Out:
# <Axes: title={'center': 'Population Benefited by Water Bodies per District'}, xlabel='District Name'>

# %%
df.groupby('District Name')['ipc_water_body'] \
  .sum() \
  .sort_values(ascending=False) \
  .plot(
      kind='bar',
      figsize=(12,6),
      title='Total Irrigation Potential by District'
  )
# Out:
# <Axes: title={'center': 'Total Irrigation Potential by District'}, xlabel='District Name'>

# %%
df['capacity_loss'] = df['storage_capacity_water_body_original'] - df['storage_capacity_water_body_present']
df.groupby('District Name')['capacity_loss'] \
  .mean() \
  .sort_values(ascending=False) \
  .plot(
      kind='bar',
      figsize=(12,6),
      title='Average Storage Capacity Loss per District'
  )
# Out:
# <Axes: title={'center': 'Average Storage Capacity Loss per District'}, xlabel='District Name'>

# %%
df['ref_water_body_type_id_name'] \
  .value_counts() \
  .plot(
      kind='pie',
      figsize=(5,5),
      autopct='%1.1f%%',
      title='Distribution of Water Body Types',
      ylabel=''
  )
# Out:
# <Axes: title={'center': 'Distribution of Water Body Types'}>

# %%
df['ref_reason_water_body_in_use_id1_name'] \
  .value_counts() \
  .plot(
      kind='bar',
      figsize=(10,6),
      title='Purpose of Water Body Usage'
  )
# Out:
# <Axes: title={'center': 'Purpose of Water Body Usage'}, xlabel='ref_reason_water_body_in_use_id1_name'>

# %%
df.groupby('District Name')['water_spread_area_of_water_body'] \
  .mean() \
  .sort_values(ascending=False) \
  .plot(
      kind='bar',
      figsize=(12,6),
      title='Average Water Spread Area of Water Bodies by District'
  )
# Out:
# <Axes: title={'center': 'Average Water Spread Area of Water Bodies by District'}, xlabel='District Name'>

# %%
df.groupby('District Name')['max_depth_water_body_fully_filled'] \
  .mean() \
  .sort_values(ascending=False) \
  .plot(
      kind='bar',
      figsize=(12,6),
      title='Average Maximum Depth of Water Bodies by District'
  )
# Out:
# <Axes: title={'center': 'Average Maximum Depth of Water Bodies by District'}, xlabel='District Name'>

# %%
import numpy as np

# 1. Remove unstable rows (very small capacity)
df = df[df['storage_capacity_water_body_original'] > 100]

# 2. Create efficiency
df['efficiency_ratio'] = (
    df['storage_capacity_water_body_present'] /
    df['storage_capacity_water_body_original']
)

# 3. Create loss
df['loss_percentage'] = (
    (df['storage_capacity_water_body_original'] - df['storage_capacity_water_body_present']) /
    df['storage_capacity_water_body_original']
)

# 4. Fix people scale
df['people_benefited'] = np.log1p(df['no_people_benefited_by_water_body'])

# %%
df[['efficiency_ratio','loss_percentage','people_benefited']].describe()
# Out:
#        efficiency_ratio  loss_percentage  people_benefited
# count      1.685250e+05    168525.000000     168525.000000
# mean       1.147450e+00        -0.147450          1.644845
# std        2.616947e+01        26.169465          1.399678
# min        2.000000e-07     -6665.666667          0.693147
# 25%        7.435897e-01         0.000000          0.693147
# 50%        7.435897e-01         0.256410          1.098612
# 75%        1.000000e+00         0.256410          1.945910
# max        6.666667e+03         1.000000         13.592368

# %%
df = df[
    df['storage_capacity_water_body_present'] <=
    df['storage_capacity_water_body_original']
]

# %%
# Efficiency
df['efficiency_ratio'] = (
    df['storage_capacity_water_body_present'] /
    df['storage_capacity_water_body_original']
)

# Loss (correct now)
df['loss_percentage'] = (
    (df['storage_capacity_water_body_original'] - df['storage_capacity_water_body_present']) /
    df['storage_capacity_water_body_original']
)

# %%
df[['efficiency_ratio','loss_percentage','people_benefited']].describe()
# Out:
#        efficiency_ratio  loss_percentage  people_benefited
# count      1.644910e+05    164491.000000     164491.000000
# mean       7.606734e-01         0.239327          1.641609
# std        2.339656e-01         0.233966          1.396396
# min        2.000000e-07         0.000000          0.693147
# 25%        7.435897e-01         0.017544          0.693147
# 50%        7.435897e-01         0.256410          1.098612
# 75%        9.824561e-01         0.256410          1.945910
# max        1.000000e+00         1.000000         13.592368

# %%
from sklearn.preprocessing import StandardScaler

features = ['efficiency_ratio', 'loss_percentage', 'people_benefited']
X = df[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 0    124239
# 2     25940
# 1     14312
# Name: count, dtype: int64

# %%
df.groupby('cluster')[features].mean()
# Out:
#          efficiency_ratio  loss_percentage  people_benefited
# cluster
# 0                0.815597         0.184403          1.059467
# 1                0.142826         0.857174          2.228762
# 2                0.838508         0.161492          4.105811

# %%
cluster_names = {
    0: "Underutilized (Healthy, Low Impact)",
    1: "Critical (Highly Degraded)",
    2: "High-Value (Efficient & High Impact)"
}

df['cluster_label'] = df['cluster'].map(cluster_names)

# %%
df['cluster_label'].value_counts()
# Out:
# cluster_label
# Underutilized (Healthy, Low Impact)     124239
# High-Value (Efficient & High Impact)     25940
# Critical (Highly Degraded)               14312
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# counts
counts = df['cluster_label'].value_counts()

plt.figure(figsize=(6,6))

sns.scatterplot(
    data=sample_df,
    x='efficiency_ratio',
    y='people_benefited',
    hue='cluster_label',
    palette={
        "Underutilized (Healthy, Low Impact)": "blue",
        "Critical (Highly Degraded)": "orange",
        "High-Value (Efficient & High Impact)": "green"
    },
    alpha=0.6
)

#  BIG BOLD LABELS WITH BOXES
plt.text(
    0.7, 1.8,
    f"UNDERUTILIZED\n{counts['Underutilized (Healthy, Low Impact)']:,}",
    fontsize=12, fontweight='bold', color='blue',
    bbox=dict(facecolor='white', alpha=0.8)
)

plt.text(
    0.1, 6,
    f"CRITICAL\n{counts['Critical (Highly Degraded)']:,}",
    fontsize=12, fontweight='bold', color='orange',
    bbox=dict(facecolor='white', alpha=0.8)
)

plt.text(
    0.75, 9,
    f"HIGH VALUE\n{counts['High-Value (Efficient & High Impact)']:,}",
    fontsize=12, fontweight='bold', color='green',
    bbox=dict(facecolor='white', alpha=0.8)
)

plt.title('Water Body Clusters: Efficiency vs Impact', fontsize=14, fontweight='bold')
plt.xlabel('Efficiency Ratio')
plt.ylabel('People Benefited (log)')

plt.legend(title='Cluster Type')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))  # increase width

sns.countplot(x='cluster_label', data=df)

plt.xticks(rotation=30, ha='right')  # fix overlap
plt.tight_layout()  # prevents cut-off

plt.show()

# %%
district_cluster = df.groupby(['District Name', 'cluster_label']).size().unstack(fill_value=0)
district_cluster
# Out:
# cluster_label  Critical (Highly Degraded)  \
# District Name
# ANANTHAPUR                            745
# CHITTOOR                             2652
# EAST GODAVARI                         838
# GUNTUR                                432
# KRISHNA                              1832
# KURNOOL                               116
# PRAKASAM                              761
# SPS NELLORE                           369
# SRIKAKULAM                           1803
# VISAKHAPATNAM                        1292
# VIZIANAGARAM                         1553
# WEST GODAVARI                        1417
# YSR                                   502
#
# cluster_label  High-Value (Efficient & High Impact)  \
# District Name
# ANANTHAPUR                                     4629
# CHITTOOR                                        961
# EAST GODAVARI                                  1705
# GUNTUR                                          290
# KRISHNA                                        1611
# KURNOOL                                         477
# PRAKASAM                                        681
# SPS NELLORE                                     728
# SRIKAKULAM                                     5205
# VISAKHAPATNAM                                  3098
# VIZIANAGARAM                                   4376
# WEST GODAVARI                                  1461
# YSR                                             718
#
# cluster_label  Underutilized (Healthy, Low Impact)
# District Name
# ANANTHAPUR                                   40756
# CHITTOOR                                      2851
# EAST GODAVARI                                17810
# GUNTUR                                        1269
# KRISHNA                                      18247
# KURNOOL                                       2661
# PRAKASAM                                      2179
# SPS NELLORE                                   1359
# SRIKAKULAM                                    1260
# VISAKHAPATNAM                                 5216
# VIZIANAGARAM                                  1633
# WEST GODAVARI                                24180
# YSR                                           4818

# %%
district_cluster_percent_sorted = district_cluster_percent.sort_values(
    by='Underutilized (Healthy, Low Impact)',
    ascending=False
)

district_cluster_percent_sorted
# Out:
# cluster_label  Critical (Highly Degraded)  \
# District Name
# WEST GODAVARI                    5.236899
# ANANTHAPUR                       1.615001
# EAST GODAVARI                    4.117329
# KRISHNA                          8.446289
# KURNOOL                          3.564843
# YSR                              8.314011
# GUNTUR                          21.697639
# PRAKASAM                        21.016294
# SPS NELLORE                     15.024430
# VISAKHAPATNAM                   13.449927
# CHITTOOR                        41.027228
# VIZIANAGARAM                    20.536895
# SRIKAKULAM                      21.806967
#
# cluster_label  High-Value (Efficient & High Impact)  \
# District Name
# WEST GODAVARI                              5.399512
# ANANTHAPUR                                10.034685
# EAST GODAVARI                              8.377143
# KRISHNA                                    7.427386
# KURNOOL                                   14.658881
# YSR                                       11.891355
# GUNTUR                                    14.565545
# PRAKASAM                                  18.806959
# SPS NELLORE                               29.641694
# VISAKHAPATNAM                             32.250677
# CHITTOOR                                  14.866955
# VIZIANAGARAM                              57.868289
# SRIKAKULAM                                62.953556
#
# cluster_label  Underutilized (Healthy, Low Impact)
# District Name
# WEST GODAVARI                            89.363589
# ANANTHAPUR                               88.350314
# EAST GODAVARI                            87.505527
# KRISHNA                                  84.126325
# KURNOOL                                  81.776275
# YSR                                      79.794634
# GUNTUR                                   63.736816
# PRAKASAM                                 60.176747
# SPS NELLORE                              55.333876
# VISAKHAPATNAM                            54.299396
# CHITTOOR                                 44.105817
# VIZIANAGARAM                             21.594816
# SRIKAKULAM                               15.239478

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.tree import plot_tree
cat_cols = [
    "rural_or_urban", "water_body_ownership_name",
    "ref_water_body_in_use_id_name", "ref_reason_water_body_in_use_id1_name",
    "ref_selection_id_wua_exists_name", "ref_selection_id_dip_sip_exists_name",
    "ref_selection_id_water_body_encroached_name",
    "ref_water_body_under_repair_renovation_restoration_id_name",
    "filled_up_storage_name", "water_body_nature_name", "ref_water_body_type_id_name",
]
num_cols = [
    "efficiency_ratio", "loss_percentage",
    "storage_capacity_water_body_present", "storage_capacity_water_body_original",
    "water_spread_area_of_water_body", "no_people_benefited_by_water_body",
    "no_villages_benefited", "cca_water_body",
]

cat_cols = [c for c in cat_cols if c in df.columns]
num_cols = [c for c in num_cols if c in df.columns]

# Encode
df_model = df.copy()
le = LabelEncoder()
for col in cat_cols:
    df_model[col] = le.fit_transform(df_model[col].astype(str))
for col in num_cols:
    df_model[col] = df_model[col].fillna(df_model[col].median())

feature_cols = cat_cols + num_cols
X = df_model[feature_cols]
y = df_model["cluster_label"]

# Train
dt = DecisionTreeClassifier(max_depth=4, min_samples_leaf=50, random_state=42)
dt.fit(X, y)

# Print text rules
print("=" * 60)
print("DECISION TREE RULES")
print("=" * 60)
print(export_text(dt, feature_names=feature_cols))



# ── Decision Tree IMAGE ──────────────────────────────────────
fig, ax = plt.subplots(figsize=(28, 10))
plot_tree(
    dt,
    feature_names=feature_cols,
    class_names=dt.classes_,
    filled=True,
    rounded=True,
    fontsize=9,
    ax=ax,
    impurity=False,
    proportion=False,
)
plt.title("Decision Tree — AP Water Body Cluster Classification", fontsize=16, fontweight="bold", pad=20)
plt.tight_layout()
plt.savefig("decision_tree.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
print("\nAPRIORI RULES PER CLUSTER\n")

for cluster in df["cluster_label"].unique():

    print("\n----------------------------------------")
    print("Cluster:", cluster)
    print("----------------------------------------")

    subset = df[df["cluster_label"] == cluster]

    print("Records:", len(subset))

    data = pd.get_dummies(subset[cat_cols])

    data = data.loc[:, (data.mean() > 0.05) & (data.mean() < 0.95)]

    if data.shape[1] < 2:
        print("Not enough data")
        continue

    freq = apriori(data, min_support=0.1, use_colnames=True)

    if freq.empty:
        print("No frequent items")
        continue


    rules = association_rules(freq, metric="lift", min_threshold=1)

    if rules.empty:
        print("No strong rules")
        continue

    # sort by lift and take top 8
    rules = rules.sort_values(by="lift", ascending=False).head(8)

    print("\nTop Rules (based on lift):\n")

    for _, row in rules.iterrows():
        left = ', '.join(list(row['antecedents']))
        right = ', '.join(list(row['consequents']))

        print("IF", left)
        print("THEN", right)
        print(f"support={row['support']:.3f}, confidence={row['confidence']:.3f}, lift={row['lift']:.3f}")
        print()
        print("-" * 40)
        print()

print("\nDONE")
